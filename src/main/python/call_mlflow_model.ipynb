# %%
import mlflow

# %%
model_name = "xgb-boston"
stage = "Production"

model = mlflow.pyfunc.load_model(
    model_uri=f"models:/{model_name}/{stage}"
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ra144\IdeaProjects\MachineLearning\mlenv\lib\site-packages\mlflow\tracking\registry.py:76, in StoreRegistry.get_store_builder(self, store_uri)
#      75 try:
# ---> 76     store_builder = self._registry[scheme]
#      77 except KeyError:
#
# KeyError: 'file'
#
# During handling of the above exception, another exception occurred:
#
# UnsupportedModelRegistryStoreURIException Traceback (most recent call last)
# File c:\Users\ra144\IdeaProjects\MachineLearning\mlenv\lib\site-packages\mlflow\tracking\client.py:95, in MlflowClient._get_registry_client(self)
#      94 try:
# ---> 95     registry_client = ModelRegistryClient(self._registry_uri)
#      96     # Define an instance variable on this `MlflowClient` instance to reference the
# ...
